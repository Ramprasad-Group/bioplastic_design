# %%
import pandas as pd
from pathlib import Path
df = pd.read_pickle('predictions_01_11_2022.pkl')
df = df.fillna('')

# %%
# Reorder columns
order = ['comp', 'Tg', 'Tm',  'YM', 'TS_b',  'eps_b', 'perm_O2', 'perm_CO2', 'Td', 'TS_y', 'perm_N2',  
       'perm_H2',  'perm_He',   'perm_CH4', 'smiles', 'num_side', 'num_back', 'end_group', 'names']
df = df[order]
df
# Out:
#          comp          Tg          Tm           YM       TS_b       eps_b  \
# 0         0.0  246.341049  354.051544   773.208252  32.409279  103.836082
# 1         0.1  313.798401  449.257751  1866.776855  38.010651    7.215131
# 2         0.2  306.681305  446.618713  1769.267456  37.998493    8.727348
# 3         0.3  298.431488  442.813019  1653.973633  37.676380   10.997544
# 4         0.4  290.073944  436.398560  1508.705688  36.907192   14.239414
# ...       ...         ...         ...          ...        ...         ...
# 1373498   0.0  325.252380  462.438263  2680.520020  68.497833   30.515642
# 1373499   0.0  369.788818  509.966248  2227.901367  37.865055    1.950041
# 1373500   0.0  344.375183  457.250885  1724.992798  46.697941   27.839941
# 1373501   0.0  393.653473  536.671326  1942.565186  65.647507   27.729816
# 1373502   0.0  317.276978  469.612549  1508.900513  40.808701    4.400261
#
#           perm_O2   perm_CO2          Td       TS_y   perm_N2    perm_H2  \
# 0       -0.074397  -0.109570  524.699646  25.838213 -0.071000   0.296051
# 1       -0.043089  -0.006026  502.616241  44.379429 -0.049233   0.342873
# 2       -0.050900  -0.028856  502.605896  44.743877 -0.060321   0.322175
# 3       -0.057812  -0.048113  503.664642  44.287182 -0.069126   0.314363
# 4       -0.065853  -0.065725  505.013275  42.840149 -0.075789   0.302125
# ...           ...        ...         ...        ...       ...        ...
# 1373498  0.011635  -0.060768  502.465759  39.839355  0.002471   0.056135
# 1373499  2.547638  11.337365  587.491455  33.554047  0.559539  24.865118
# 1373500  0.099392   0.332474  574.055664  50.262169 -0.005775   1.482780
# 1373501  0.016741   0.138303  700.403137  44.805931 -0.054595   1.336078
# 1373502 -0.004739  -0.059302  686.914612  54.058247  0.014024   0.000020
#
#            perm_He  perm_CH4  \
# 0         0.493981 -0.061771
# 1         0.462577 -0.031425
# 2         0.455602 -0.039934
# 3         0.458959 -0.047438
# 4         0.461121 -0.055182
# ...            ...       ...
# 1373498   0.179605  0.001415
# 1373499  21.572718  0.881040
# 1373500   1.581858  0.070204
# 1373501   1.767082 -0.069961
# 1373502   0.252653  0.044955
#
#                                                     smiles      num_side  \
# 0                         ([*]OCCC(=O)[*], [*]OCCC(=O)[*])        (0, 0)
# 1                      ([*]OCCC(=O)[*], [*]OC(O)CC(=O)[*])        (0, 0)
# 2                      ([*]OCCC(=O)[*], [*]OC(O)CC(=O)[*])        (0, 0)
# 3                      ([*]OCCC(=O)[*], [*]OC(O)CC(=O)[*])        (0, 0)
# 4                      ([*]OCCC(=O)[*], [*]OC(O)CC(=O)[*])        (0, 0)
# ...                                                    ...           ...
# 1373498                         ([*]CC([*])O, [*]CC([*])O)  (None, None)
# 1373499           ([*]CC([*])c1ccccc1, [*]CC([*])c1ccccc1)  (None, None)
# 1373500                       ([*]CC([*])Cl, [*]CC([*])Cl)  (None, None)
# 1373501  ([*]CCOC(=O)c1ccc2cc(C(=O)O[*])ccc2c1, [*]CCOC...  (None, None)
# 1373502             ([*]CCCCCC(=O)N[*], [*]CCCCCC(=O)N[*])  (None, None)
#
#              num_back     end_group             names
# 0              (3, 3)          (, )        (pha, pha)
# 1              (3, 3)         (, O)        (pha, pha)
# 2              (3, 3)         (, O)        (pha, pha)
# 3              (3, 3)         (, O)        (pha, pha)
# 4              (3, 3)         (, O)        (pha, pha)
# ...               ...           ...               ...
# 1373498  (None, None)  (None, None)        (PVA, PVA)
# 1373499  (None, None)  (None, None)          (PS, PS)
# 1373500  (None, None)  (None, None)        (PVC, PVC)
# 1373501  (None, None)  (None, None)        (PEN, PEN)
# 1373502  (None, None)  (None, None)  (Nylon6, Nylon6)
#
# [1373503 rows x 19 columns]

# %%
# Get value count
df.names.value_counts()
# Out:
# (pha, pha)                            1310310
# (pha, PEG)                               4860
# (pha, PE)                                4860
# (pha, PEN)                               4860
# (pha, PVC)                               4860
# (pha, PS)                                4860
# (pha, PVA)                               4860
# (pha, Nylon6)                            4860
# (pha, PET)                               4860
# (pha, poly(hexylene))                    4860
# (pha, poly(pentylene))                   4860
# (pha, PB)                                4860
# (pha, PP)                                4860
# (pha, [*]CC([*])C(C)C)                   4860
# (PET, PET)                                  1
# (PEN, PEN)                                  1
# (PVC, PVC)                                  1
# (PS, PS)                                    1
# (PVA, PVA)                                  1
# (PEG, PEG)                                  1
# (poly(pentylene), poly(pentylene))          1
# ([*]CC([*])C(C)C, [*]CC([*])C(C)C)          1
# (poly(hexylene), poly(hexylene))            1
# (PB, PB)                                    1
# (PP, PP)                                    1
# (PE, PE)                                    1
# (Nylon6, Nylon6)                            1
# Name: names, dtype: int64

# %%
df_exp = pd.read_pickle('exp_values.pkl')
df_exp
# Out:
#                           Polymer     Abb.  \
# 0                  Poly(ethylene)       PE
# 1                 Poly(propylene)       PP
# 2            Poly(vinyl chloride)      PVC
# 3    Poly(ethylene terephthalate)      PET
# 4                   Poly(styrene)       PS
# 5           Poly(hexano-6-lactam)  Nylon 6
# 6  Poly(ethylene 2,6-naphthalate)      PEN
#
#                                         applications  \
# 0  Cloth packaging, T-shirt shopping bags, waste ...
# 1                Living hinges, pipes, caps, cutlery
# 2                Window frames, cables, pipes, films
# 3                       Bottles, automotive industry
# 4  Packaging fillers, cutlery, foam cups, take-ou...
# 5                                      Yarns, fibers
# 6  Bottles, scintillators, medical product contai...
#
#                                  smiles %-usage     Tg     Tm   TS_b  eps_b  \
# 0                              [*]CC[*]    29.2  220.0  403.0   22.0  338.0
# 1                           [*]CC([*])C    19.3  287.0  437.0   30.0  150.0
# 2                          [*]CC([*])Cl     9.9  353.0  485.0   36.0   29.7
# 3        [*]CCOC(=O)c1ccc(C(=O)O[*])cc1     7.9  350.0  526.0  119.0   65.0
# 4                    [*]CC([*])c1ccccc1     6.8  371.0  528.0   34.0    2.0
# 5                     [*]CCCCCC(=O)N[*]       2  324.0  493.0   60.0   61.0
# 6  [*]CCOC(=O)c1ccc2cc(C(=O)O[*])ccc2c1          357.0  541.0   77.0   42.0
#
#        YM   perm_O2  perm_CO2    source
# 0   670.0  2.000000   27.1000  Polyinfo
# 1  1600.0  0.760000    4.4000  Polyinfo
# 2  1680.0  0.061575    0.2345  Polyinfo
# 3  2970.0  0.054000    0.3260  Polyinfo
# 4  2450.0  2.600000   12.6000  Polyinfo
# 5  1600.0  4.000000    0.0860  Polyinfo
# 6  2310.0  0.018900    0.2390  PolyInfo

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

# props to match
search_props = ['Tg', 'Tm', 'TS_b', 'YM',  'eps_b', 'perm_O2', 'perm_CO2']

# weights 
weights = np.array([1, 1, 1, 1, 1, 1, 1])
params = dict(
    metric='wminkowski',
    metric_params={'w': weights},
    p=2
)

# PHAs only
df_pha_only = df[df.names == ('pha', 'pha')]
nn_pha = NearestNeighbors(**params).fit(df_pha_only[search_props])

# All others (with conventional polymers)
df_pha_conv = df[df.names != ('pha', 'pha')]
nn_conv = NearestNeighbors(**params).fit(df_pha_conv[search_props])

# %% [markdown]
# # Nearest Neighbor for phas phas

# %%
n_neighbors = 5 
results = []
for n, row in df_exp.iterrows():
    r = row[search_props]
    dist, idx = nn_pha.kneighbors(r.to_frame().T, n_neighbors)
    res = df_pha_only.iloc[idx[0]].copy()
    res.insert(0, 'polymer', row.Polymer)
    res.insert(1, 'abb', row['Abb.'])
    res.insert(1, 'type', 'pha_only')

    diff = res[search_props] - r.to_frame().T.values
    diff = diff.add_prefix('d_')
    res = pd.concat([res, diff], axis=1)
    results.append(res)

    dist, idx = nn_conv.kneighbors(r.to_frame().T, n_neighbors)
    res = df_pha_conv.iloc[idx[0]].copy()
    res.insert(0, 'polymer', row.Polymer)
    res.insert(1, 'abb', row['Abb.'])
    res.insert(2, 'type', 'pha_conv')

    diff = res[search_props] - r.to_frame().T.values
    diff = diff.add_prefix('d_')
    res = pd.concat([res, diff], axis=1)

    results.append(res)

df_res = pd.concat(results).set_index(['polymer', 'type'])  

df_res.insert(0, 'smiles', df_res.pop('smiles'))
df_res.insert(0, 'names', df_res.pop('names'))

pp = Path('export')
pp.mkdir(exist_ok=True)
df_res.to_csv(pp / 'candidates.csv')
df_res[df_res.abb == 'PE']
# Out:
#                                           names  \
# polymer        type
# Poly(ethylene) pha_only              (pha, pha)
#                pha_only              (pha, pha)
#                pha_only              (pha, pha)
#                pha_only              (pha, pha)
#                pha_only              (pha, pha)
#                pha_conv  (pha, poly(pentylene))
#                pha_conv  (pha, poly(pentylene))
#                pha_conv  (pha, poly(pentylene))
#                pha_conv  (pha, poly(pentylene))
#                pha_conv   (pha, poly(hexylene))
#
#                                                                     smiles  \
# polymer        type
# Poly(ethylene) pha_only  ([*]OCCCC(=O)[*], [*]OC(O(c1ccc(F)cc1(F)))CCC(...
#                pha_only  ([*]OC(O(c1cccc(C)c1))CCC(=O)[*], [*]OC(CCC(=O...
#                pha_only  ([*]OC(O(c1cccc(C)c1))CCC(=O)[*], [*]OC(CCC)CC...
#                pha_only  ([*]OC(O(c1cccc(C)c1))CCC(=O)[*], [*]OC(CCCCC)...
#                pha_only  ([*]OC(O(c1cccc(C)c1))CCC(=O)[*], [*]OC(CC)CCC...
#                pha_conv        ([*]OC(Cc1ccccc1)CCC(=O)[*], [*]CC([*])CCC)
#                pha_conv       ([*]OC(c1ccccc1)CCCCC(=O)[*], [*]CC([*])CCC)
#                pha_conv       ([*]OC(CCc1ccccc1)CCC(=O)[*], [*]CC([*])CCC)
#                pha_conv    ([*]OC(Cc1ccc(C)cc1)CCCC(=O)[*], [*]CC([*])CCC)
#                pha_conv        ([*]OC(c1ccccc1)CCC(=O)[*], [*]CC([*])CCCC)
#
#                         abb  comp          Tg          Tm          YM  \
# polymer        type
# Poly(ethylene) pha_only  PE   0.5  258.494995  383.849609  681.497437
#                pha_only  PE   0.5  261.326141  379.584290  665.535095
#                pha_only  PE   0.7  261.024841  382.775208  666.938354
#                pha_only  PE   0.7  263.902710  386.395508  660.489990
#                pha_only  PE   0.7  261.819763  382.909302  679.959961
#                pha_conv  PE   0.3  249.172806  416.685577  674.920898
#                pha_conv  PE   0.4  252.273651  400.950226  660.557800
#                pha_conv  PE   0.4  247.559052  397.789978  688.662598
#                pha_conv  PE   0.5  255.428741  397.106232  661.003418
#                pha_conv  PE   0.3  251.877487  402.407654  649.265747
#
#                               TS_b       eps_b   perm_O2  ...   num_side  \
# polymer        type                                       ...
# Poly(ethylene) pha_only  42.700241  254.922684  0.095418  ...     (0, 0)
#                pha_only  35.446228  264.022095  0.114334  ...     (0, 2)
#                pha_only  32.101040  148.542191  0.220764  ...     (0, 3)
#                pha_only  33.695404  203.184418  0.258192  ...     (0, 5)
#                pha_only  32.537735  148.392059  0.207352  ...     (0, 2)
#                pha_conv  29.934265  138.532822  2.435858  ...  (1, None)
#                pha_conv  28.453552  135.639694  2.261201  ...  (0, None)
#                pha_conv  30.838322  128.668060  2.297484  ...  (2, None)
#                pha_conv  28.023664  145.875534  2.476105  ...  (1, None)
#                pha_conv  30.199499  168.341965  3.566218  ...  (0, None)
#
#                           num_back                  end_group       d_Tg  \
# polymer        type
# Poly(ethylene) pha_only     (4, 4)      (, O(c1ccc(F)cc1(F)))  38.494995
#                pha_only     (4, 4)  (O(c1cccc(C)c1), C(=O)OC)  41.326141
#                pha_only     (4, 6)         (O(c1cccc(C)c1), )  41.024841
#                pha_only     (4, 4)         (O(c1cccc(C)c1), )   43.90271
#                pha_only     (4, 6)         (O(c1cccc(C)c1), )  41.819763
#                pha_conv  (4, None)           (c1ccccc1, None)  29.172806
#                pha_conv  (6, None)           (c1ccccc1, None)  32.273651
#                pha_conv  (4, None)           (c1ccccc1, None)  27.559052
#                pha_conv  (5, None)        (c1ccc(C)cc1, None)  35.428741
#                pha_conv  (4, None)           (c1ccccc1, None)  31.877487
#
#                               d_Tm     d_TS_b       d_YM     d_eps_b  \
# polymer        type
# Poly(ethylene) pha_only -19.150391  20.700241  11.497437  -83.077316
#                pha_only  -23.41571  13.446228  -4.464905  -73.977905
#                pha_only -20.224792   10.10104  -3.061646 -189.457809
#                pha_only -16.604492  11.695404   -9.51001 -134.815582
#                pha_only -20.090698  10.537735   9.959961 -189.607941
#                pha_conv  13.685577   7.934265   4.920898 -199.467178
#                pha_conv  -2.049774   6.453552    -9.4422 -202.360306
#                pha_conv  -5.210022   8.838322  18.662598  -209.33194
#                pha_conv  -5.893768   6.023664  -8.996582 -192.124466
#                pha_conv  -0.592346   8.199499 -20.734253 -169.658035
#
#                         d_perm_O2 d_perm_CO2
# polymer        type
# Poly(ethylene) pha_only -1.904582 -26.720196
#                pha_only -1.885666 -26.539796
#                pha_only -1.779236 -26.066528
#                pha_only -1.741808 -25.920221
#                pha_only -1.792648 -26.111758
#                pha_conv  0.435858 -16.084147
#                pha_conv  0.261201 -15.984479
#                pha_conv  0.297484 -16.565551
#                pha_conv  0.476105 -15.551861
#                pha_conv  1.566218 -10.017139
#
# [10 rows x 27 columns]

# %%
from rdkit import Chem
from rdkit.Chem import Draw

import numpy as np

for name, gr in df_res.reset_index().groupby(by="abb", sort=False):
    sms = np.array([[x[0], x[1]] for x in gr.smiles.values])
    mols = [Chem.MolFromSmiles(x) for x in sms.flatten()]
    comps = gr.comp.values

    for num, sm in enumerate(sms):
        sms[num][0] = f"{round(comps[num],2)}: {sms[num][0]}"
    nn = name.lower().replace(" ", "")
    img = Draw.MolsToGridImage(
        mols,
        subImgSize=(200, 200),
        molsPerRow=2,
        maxMols=200,
        useSVG=True,
        legends=sms.flatten().tolist(),
    )
    Path(pp / f"{nn}.svg").write_text(img.data)
